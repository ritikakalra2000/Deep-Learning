# %%
# Part 1 - Data Preprocessing

# Importing the libraries
import pandas as pd

url = 'https://raw.githubusercontent.com/ritikakalra2000/google-collab/main/Churn_Modelling.csv'
dataset = pd.read_csv(url)
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, -1]

X = X.values
y = y.values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])

labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])


from sklearn.compose import ColumnTransformer 
ct = ColumnTransformer([("Country", OneHotEncoder(),[1])], remainder="passthrough") # The last arg ([0]) is the list of columns you want to transform in this step
X = ct.fit_transform(X) 
X = X[:, 1:]

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import tensorflow as tf
print ("TensorFlow version: " + tf.__version__)



from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer (2 layers are added by this one function call)
# units = 6 comes from average of input layer + output layer (11 + 1)/2
classifier.add(Dense(input_dim = 11, units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
# For a logistic regression, we dont use the sum of squared residual loss function
# We use binary cross entropy if we have 1 binary outcome and
# categorical cross entropy if we have more than one categorical outcome
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# TensorFlow version: 2.4.1
# Epoch 1/100
# 800/800 [==============================] - 1s 913us/step - loss: 0.5639 - accuracy: 0.8009
# Epoch 2/100
# 800/800 [==============================] - 1s 905us/step - loss: 0.4337 - accuracy: 0.7951
# Epoch 3/100
# 800/800 [==============================] - 1s 909us/step - loss: 0.4259 - accuracy: 0.8031
# Epoch 4/100
# 800/800 [==============================] - 1s 929us/step - loss: 0.4079 - accuracy: 0.8342
# Epoch 5/100
# 800/800 [==============================] - 1s 883us/step - loss: 0.4090 - accuracy: 0.8348
# Epoch 6/100
# 800/800 [==============================] - 1s 906us/step - loss: 0.4076 - accuracy: 0.8306
# Epoch 7/100
# 800/800 [==============================] - 1s 916us/step - loss: 0.4134 - accuracy: 0.8292
# Epoch 8/100
# 800/800 [==============================] - 1s 894us/step - loss: 0.4025 - accuracy: 0.8382
# Epoch 9/100
# 800/800 [==============================] - 1s 896us/step - loss: 0.3966 - accuracy: 0.8397
# Epoch 10/100
# 800/800 [==============================] - 1s 900us/step - loss: 0.4073 - accuracy: 0.8360
# Epoch 11/100
# 800/800 [==============================] - 1s 914us/step - loss: 0.4027 - accuracy: 0.8375
# Epoch 12/100
# 800/800 [==============================] - 1s 892us/step - loss: 0.4044 - accuracy: 0.8350
# Epoch 13/100
# 800/800 [==============================] - 1s 907us/step - loss: 0.4100 - accuracy: 0.8299
# Epoch 14/100
# 800/800 [==============================] - 1s 923us/step - loss: 0.4068 - accuracy: 0.8314
# Epoch 15/100
# 800/800 [==============================] - 1s 919us/step - loss: 0.3984 - accuracy: 0.8338
# Epoch 16/100
# 800/800 [==============================] - 1s 886us/step - loss: 0.3961 - accuracy: 0.8412
# Epoch 17/100
# 800/800 [==============================] - 1s 890us/step - loss: 0.3937 - accuracy: 0.8369
# Epoch 18/100
# 800/800 [==============================] - 1s 964us/step - loss: 0.4089 - accuracy: 0.8289
# Epoch 19/100
# 800/800 [==============================] - 1s 917us/step - loss: 0.4059 - accuracy: 0.8309
# Epoch 20/100
# 800/800 [==============================] - 1s 975us/step - loss: 0.3882 - accuracy: 0.8399
# Epoch 21/100
# 800/800 [==============================] - 1s 910us/step - loss: 0.3919 - accuracy: 0.8392
# Epoch 22/100
# 800/800 [==============================] - 1s 910us/step - loss: 0.4006 - accuracy: 0.8357
# Epoch 23/100
# 800/800 [==============================] - 1s 932us/step - loss: 0.3883 - accuracy: 0.8389
# Epoch 24/100
# 800/800 [==============================] - 1s 882us/step - loss: 0.4081 - accuracy: 0.8286
# Epoch 25/100
# 800/800 [==============================] - 1s 923us/step - loss: 0.3991 - accuracy: 0.8342
# Epoch 26/100
# 800/800 [==============================] - 1s 925us/step - loss: 0.3970 - accuracy: 0.8376
# Epoch 27/100
# 800/800 [==============================] - 1s 888us/step - loss: 0.3956 - accuracy: 0.8368
# Epoch 28/100
# 800/800 [==============================] - 1s 916us/step - loss: 0.4072 - accuracy: 0.8305
# Epoch 29/100
# 800/800 [==============================] - 1s 924us/step - loss: 0.4040 - accuracy: 0.8345
# Epoch 30/100
# 800/800 [==============================] - 1s 900us/step - loss: 0.3968 - accuracy: 0.8386
# Epoch 31/100
# 800/800 [==============================] - 1s 868us/step - loss: 0.4107 - accuracy: 0.8283
# Epoch 32/100
# 800/800 [==============================] - 1s 946us/step - loss: 0.3928 - accuracy: 0.8390
# Epoch 33/100
# 800/800 [==============================] - 1s 905us/step - loss: 0.3987 - accuracy: 0.8359
# Epoch 34/100
# 800/800 [==============================] - 1s 877us/step - loss: 0.4070 - accuracy: 0.8329
# Epoch 35/100
# 800/800 [==============================] - 1s 912us/step - loss: 0.4029 - accuracy: 0.8332
# Epoch 36/100
# 800/800 [==============================] - 1s 932us/step - loss: 0.3926 - accuracy: 0.8397
# Epoch 37/100
# 800/800 [==============================] - 1s 929us/step - loss: 0.4062 - accuracy: 0.8331
# Epoch 38/100
# 800/800 [==============================] - 1s 911us/step - loss: 0.3962 - accuracy: 0.8374
# Epoch 39/100
# 800/800 [==============================] - 1s 908us/step - loss: 0.3975 - accuracy: 0.8372
# Epoch 40/100
# 800/800 [==============================] - 1s 928us/step - loss: 0.3913 - accuracy: 0.8383
# Epoch 41/100
# 800/800 [==============================] - 1s 895us/step - loss: 0.3992 - accuracy: 0.8340
# Epoch 42/100
# 800/800 [==============================] - 1s 943us/step - loss: 0.3863 - accuracy: 0.8425
# Epoch 43/100
# 800/800 [==============================] - 1s 922us/step - loss: 0.3942 - accuracy: 0.8407
# Epoch 44/100
# 800/800 [==============================] - 1s 906us/step - loss: 0.3871 - accuracy: 0.8416
# Epoch 45/100
# 800/800 [==============================] - 1s 897us/step - loss: 0.3939 - accuracy: 0.8380
# Epoch 46/100
# 800/800 [==============================] - 1s 895us/step - loss: 0.3852 - accuracy: 0.8410
# Epoch 47/100
# 800/800 [==============================] - 1s 912us/step - loss: 0.3734 - accuracy: 0.8482
# Epoch 48/100
# 800/800 [==============================] - 1s 924us/step - loss: 0.3766 - accuracy: 0.8429
# Epoch 49/100
# 800/800 [==============================] - 1s 935us/step - loss: 0.3759 - accuracy: 0.8394
# Epoch 50/100
# 800/800 [==============================] - 1s 904us/step - loss: 0.3723 - accuracy: 0.8429
# Epoch 51/100
# 800/800 [==============================] - 1s 929us/step - loss: 0.3655 - accuracy: 0.8458
# Epoch 52/100
# 800/800 [==============================] - 1s 916us/step - loss: 0.3592 - accuracy: 0.8502
# Epoch 53/100
# 800/800 [==============================] - 1s 931us/step - loss: 0.3555 - accuracy: 0.8533
# Epoch 54/100
# 800/800 [==============================] - 1s 892us/step - loss: 0.3616 - accuracy: 0.8523
# Epoch 55/100
# 800/800 [==============================] - 1s 931us/step - loss: 0.3513 - accuracy: 0.8510
# Epoch 56/100
# 800/800 [==============================] - 1s 940us/step - loss: 0.3478 - accuracy: 0.8542
# Epoch 57/100
# 800/800 [==============================] - 1s 935us/step - loss: 0.3620 - accuracy: 0.8461
# Epoch 58/100
# 800/800 [==============================] - 1s 933us/step - loss: 0.3617 - accuracy: 0.8469
# Epoch 59/100
# 800/800 [==============================] - 1s 909us/step - loss: 0.3446 - accuracy: 0.8529
# Epoch 60/100
# 800/800 [==============================] - 1s 908us/step - loss: 0.3597 - accuracy: 0.8521
# Epoch 61/100
# 800/800 [==============================] - 1s 915us/step - loss: 0.3479 - accuracy: 0.8562
# Epoch 62/100
# 800/800 [==============================] - 1s 910us/step - loss: 0.3448 - accuracy: 0.8562
# Epoch 63/100
# 800/800 [==============================] - 1s 923us/step - loss: 0.3279 - accuracy: 0.8683
# Epoch 64/100
# 800/800 [==============================] - 1s 963us/step - loss: 0.3438 - accuracy: 0.8581
# Epoch 65/100
# 800/800 [==============================] - 1s 910us/step - loss: 0.3407 - accuracy: 0.8586
# Epoch 66/100
# 800/800 [==============================] - 1s 932us/step - loss: 0.3436 - accuracy: 0.8599
# Epoch 67/100
# 800/800 [==============================] - 1s 896us/step - loss: 0.3488 - accuracy: 0.8563
# Epoch 68/100
# 800/800 [==============================] - 1s 920us/step - loss: 0.3358 - accuracy: 0.8622
# Epoch 69/100
# 800/800 [==============================] - 1s 918us/step - loss: 0.3381 - accuracy: 0.8598
# Epoch 70/100
# 800/800 [==============================] - 1s 934us/step - loss: 0.3448 - accuracy: 0.8529
# Epoch 71/100
# 800/800 [==============================] - 1s 923us/step - loss: 0.3422 - accuracy: 0.8616
# Epoch 72/100
# 800/800 [==============================] - 1s 924us/step - loss: 0.3464 - accuracy: 0.8513
# Epoch 73/100
# 800/800 [==============================] - 1s 886us/step - loss: 0.3331 - accuracy: 0.8619
# Epoch 74/100
# 800/800 [==============================] - 1s 952us/step - loss: 0.3420 - accuracy: 0.8625
# Epoch 75/100
# 800/800 [==============================] - 1s 943us/step - loss: 0.3425 - accuracy: 0.8592
# Epoch 76/100
# 800/800 [==============================] - 1s 957us/step - loss: 0.3297 - accuracy: 0.8672
# Epoch 77/100
# 800/800 [==============================] - 1s 938us/step - loss: 0.3365 - accuracy: 0.8624
# Epoch 78/100
# 800/800 [==============================] - 1s 912us/step - loss: 0.3429 - accuracy: 0.8561
# Epoch 79/100
# 800/800 [==============================] - 1s 914us/step - loss: 0.3346 - accuracy: 0.8605
# Epoch 80/100
# 800/800 [==============================] - 1s 959us/step - loss: 0.3372 - accuracy: 0.8583
# Epoch 81/100
# 800/800 [==============================] - 1s 919us/step - loss: 0.3434 - accuracy: 0.8586
# Epoch 82/100
# 800/800 [==============================] - 1s 896us/step - loss: 0.3446 - accuracy: 0.8556
# Epoch 83/100
# 800/800 [==============================] - 1s 903us/step - loss: 0.3376 - accuracy: 0.8576
# Epoch 84/100
# 800/800 [==============================] - 1s 956us/step - loss: 0.3407 - accuracy: 0.8595
# Epoch 85/100
# 800/800 [==============================] - 1s 924us/step - loss: 0.3456 - accuracy: 0.8539
# Epoch 86/100
# 800/800 [==============================] - 1s 927us/step - loss: 0.3385 - accuracy: 0.8596
# Epoch 87/100
# 800/800 [==============================] - 1s 903us/step - loss: 0.3372 - accuracy: 0.8576
# Epoch 88/100
# 800/800 [==============================] - 1s 951us/step - loss: 0.3478 - accuracy: 0.8533
# Epoch 89/100
# 800/800 [==============================] - 1s 880us/step - loss: 0.3460 - accuracy: 0.8525
# Epoch 90/100
# 800/800 [==============================] - 1s 897us/step - loss: 0.3218 - accuracy: 0.8658
# Epoch 91/100
# 800/800 [==============================] - 1s 908us/step - loss: 0.3454 - accuracy: 0.8588
# Epoch 92/100
# 800/800 [==============================] - 1s 923us/step - loss: 0.3463 - accuracy: 0.8581
# Epoch 93/100
# 800/800 [==============================] - 1s 881us/step - loss: 0.3424 - accuracy: 0.8579
# Epoch 94/100
# 800/800 [==============================] - 1s 912us/step - loss: 0.3492 - accuracy: 0.8539
# Epoch 95/100
# 800/800 [==============================] - 1s 918us/step - loss: 0.3415 - accuracy: 0.8573
# Epoch 96/100
# 800/800 [==============================] - 1s 910us/step - loss: 0.3417 - accuracy: 0.8592
# Epoch 97/100
# 800/800 [==============================] - 1s 912us/step - loss: 0.3422 - accuracy: 0.8558
# Epoch 98/100
# 800/800 [==============================] - 1s 946us/step - loss: 0.3487 - accuracy: 0.8582
# Epoch 99/100
# 800/800 [==============================] - 1s 950us/step - loss: 0.3288 - accuracy: 0.8586
# Epoch 100/100
# 800/800 [==============================] - 1s 937us/step - loss: 0.3415 - accuracy: 0.8526

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1526,   65],
#        [ 208,  201]])
